# %% [markdown]
# # 1.6 awk
#
# This notebook will demonstrate the basics of using `awk` to extract specific fields from within data files.

# %% [markdown]
# #### manual inspection of `artists.txt`
#
# There are at least two options for loading `artists.txt` into your favorite spreadsheet program:
#
# * you already have the file on your computer somewhere on your file system, so you can load it from there (if you can figure it out)
# * you can download the text file from https://raw.githubusercontent.com/SuLab/Applied-Bioinformatics/master/Module-1_bash-jupyter-git/data/art/artists.txt
#
# Note that every row has four columns.

# %% [markdown]
# #### confirm using awk that each row has four columns
# Find and fix the error.
#
# ```
# %%bash
# awk '{print NF}' artists.txt
# ```

# %%
# %%bash
# cd data/art
# awk '{FS="\t"; print NF}' artists.txt
# Out:
# 8
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4

# %% [markdown]
# #### Print the third column
# Find and fix the error.
# ```
# %%bash
# awk '{print $3}' artists.txt
# ```

# %%
# %%bash
# cd data/art
# awk '{FS="\t"; print $3}' artists.txt
# Out:
# (1581-1662)
# Romanticism
# Romanticism
# Romanticism
# Baroque
# Romanticism
# Baroque
# Realism
# Northern Renaissance
# Realism
# Romanticism
# Baroque
# Baroque
# Early Renaissance
# Medieval
# Early Renaissance
# Realism
# Medieval
# Medieval
# Early Renaissance
# High Renaissance
# Early Renaissance
# Baroque
# Baroque
# Baroque
# Rococo
# Neoclassicism
# Impressionism
# Baroque
# Baroque
# Mannerism
# Baroque
# Baroque
# Rococo
# Romanticism
# Baroque
# Baroque
# Rococo
# Baroque
# Baroque
# Mannerism
# Romanticism
# Rococo
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Mannerism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Romanticism
# Romanticism
# Romanticism
# Rococo
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Rococo
# Rococo
# Rococo
# Neoclassicism
# Romanticism
# Northern Renaissance
# Romanticism
# Romanticism
# Baroque
# Baroque
# Romanticism
# Northern Renaissance
# Baroque
# Baroque
# Neoclassicism
# Rococo
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Northern Renaissance
# Romanticism
# Mannerism
# Realism
# Early Renaissance
# High Renaissance
# Mannerism
# Realism
# Baroque
# High Renaissance
# Baroque
# Romanticism
# Mannerism
# Baroque
# Realism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Neoclassicism
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Early Renaissance
# Baroque
# Baroque
# Northern Renaissance
# Northern Renaissance
# Neoclassicism
# Medieval
# Early Renaissance
# Medieval
# Early Renaissance
# Medieval
# High Renaissance
# High Renaissance
# Neoclassicism
# Realism
# Rococo
# Medieval
# Early Renaissance
# Baroque
# Medieval
# Early Renaissance
# Mannerism
# Mannerism
# Early Renaissance
# Early Renaissance

# %% [markdown]
# #### Use `uniq` (and another command) to find the most common art periods
# Find and fix the error(s).
# ```
# %%bash
# awk '{print $3}' artists.txt | uniq
# ```

# %%
# %%bash
# cd data/art
# awk '{FS="\t";print $3}' artists.txt | sort -u
# Out:
# (1581-1662)
# Baroque
# Early Renaissance
# High Renaissance
# Impressionism
# Mannerism
# Medieval
# Neoclassicism
# Northern Renaissance
# Realism
# Rococo
# Romanticism

# %% [markdown]
# ## Homework

# %% [markdown]
# ### HW1: Repeat the above command (finding the most common art periods) restricting to Dutch painters only.
# HINT: start by searching/filtering for Dutch painters...

# %%
# %%bash
# cd data/art
# grep "Dutch painter" artists.txt | sort | awk '{FS="\t"; print $3}' artists.txt | sort -u
# Out:
# (1581-1662)
# Baroque
# Early Renaissance
# High Renaissance
# Impressionism
# Mannerism
# Medieval
# Neoclassicism
# Northern Renaissance
# Realism
# Rococo
# Romanticism

# %% [markdown]
# ### HW2: Find the most common last names among all artists in `artists.txt`.
# HINT: you will use `awk`, `sort`, and `uniq`, and you may use one or more of those commands multiple times

# %%
# %%bash
# cd data/art
# sort artists.txt | awk '{FS"\t"; print $1}' artists.txt | uniq -c | grep -v -F "1"
# Out:
#    2 KISS,
#    2 KLODT,
#    2 TACCA,
#    2 TADDEO
#    2 TALENTI,
#    3 TARAVAL,
#    2 TASSAERT,
#    2 TEDESCO,
#    2 TEMPESTA,
#    3 TENIERS,
#    2 TESSIN,
#    2 KNIJFF,
#    5 KNIP,
#    2 KNYFF,
#    5 KOBELL,
#    4 KONINCK,
#    4 ADAM,
#    3 AGNOLO
#    3 AGOSTINO
#    4 ALBERTI,
